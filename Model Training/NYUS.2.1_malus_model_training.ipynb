# %% [markdown]
# # NYUS.2.1.malus training

# %% [markdown]
# The model is trained using AutoGluon(1.1.0) in Python 3.10.14. However, the training data can generate a prediction model using the most updated AutoGluon package with any supported versions of Python.

# %% [markdown]
# ## Model training
# The goal of this step is to generate a model named 'NYUS2_1_malus' in a folder with same name.

# %%
#!pip install autogluon==1.1.0
import autogluon
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
df=pd.read_csv('All_LT50_data_grape_apple.csv', sep=",", header=0)

# %%
#Drop unnecessary columns
df_training = df.drop(['Date','Location','photoperiod.Daylength','DP'],axis=1)

# %%
#Randomizing train data
df_training = df_training.sample(frac=1, random_state=25)

# %%
df_training.shape
# Out:
# (11949, 171)

# %%
#Check row label (LT50)
LT50_column = 'LT50'
print("Summary of age variable: \n", df_training[LT50_column].describe())
# Out:
# Summary of age variable:
#  count    11949.000000
# mean       -21.337650
# std          5.700328
# min        -45.000000
# 25%        -24.200000
# 50%        -21.912941
# 75%        -18.331500
# max         -4.366667
# Name: LT50, dtype: float64

# %%
#Training with AutoGluon
predictor_LT50 = TabularPredictor(label=LT50_column, path="NYUS2_1_malus").fit(df_training, presets='best_quality',num_bag_folds = 10, num_stack_levels = 4)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="NYUS2_1_malus"
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=4, num_bag_folds=10, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: NYUS2_1_malus\ds_sub_fit\sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 928 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2672 seconds.
# Starting full fit now with num_stack_levels 4.
# Beginning AutoGluon training ... Time limit = 2672s
# AutoGluon will save models to "NYUS2_1_malus"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.14
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          16
# Memory Avail:       20.82 GB / 31.70 GB (65.7%)
# Disk Space Avail:   356.95 GB / 952.48 GB (37.5%)
# ===================================================
# Train Data Rows:    11949
# Train Data Columns: 170
# Label Column:       LT50
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    21270.45 MB
# 	Train Data (Original)  Memory Usage: 16.11 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 99 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 71 | ['min_temp', 'max_temp', 'within_day_range_temp', 'Naive_average_temp', 'CU', ...]
# 		('int', [])    : 98 | ['Cultivar.Aromella', 'Cultivar.Cabernet_Franc', 'Cultivar.Cabernet_Sauvignon', 'Cultivar.Cayuga_White', 'Cultivar.Chambourcin', ...]
# 		('object', []) :  1 | ['specie']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 71 | ['min_temp', 'max_temp', 'within_day_range_temp', 'Naive_average_temp', 'CU', ...]
# 		('int', ['bool']) : 99 | ['specie', 'Cultivar.Aromella', 'Cultivar.Cabernet_Franc', 'Cultivar.Cabernet_Sauvignon', 'Cultivar.Cayuga_White', ...]
# 	2.1s = Fit runtime
# 	170 features in original data used to generate 170 features in processed data.
# 	Train Data (Processed) Memory Usage: 7.60 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 2.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 5 stack levels (L1 to L5) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 711.76s of the 2669.75s of remaining time.
# 	-2.1767	 = Validation score   (-root_mean_squared_error)
# 	0.05s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 711.3s of the 2669.29s of remaining time.
# 	-2.152	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 711.02s of the 2669.01s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	-1.5329	 = Validation score   (-root_mean_squared_error)
# 	29.85s	 = Training   runtime
# 	2.97s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 675.92s of the 2633.91s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	-1.5368	 = Validation score   (-root_mean_squared_error)
# 	33.77s	 = Training   runtime
# 	1.48s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 639.23s of the 2597.23s of remaining time.
# 	-1.6978	 = Validation score   (-root_mean_squared_error)
# 	28.59s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 608.85s of the 2566.84s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.53%)
# 	-1.5377	 = Validation score   (-root_mean_squared_error)
# 	489.02s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 116.97s of the 2074.97s of remaining time.
# 	-1.6909	 = Validation score   (-root_mean_squared_error)
# 	9.25s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 105.81s of the 2063.8s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	-2.041	 = Validation score   (-root_mean_squared_error)
# 	29.89s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 73.14s of the 2031.13s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.69%)
# 	-1.5893	 = Validation score   (-root_mean_squared_error)
# 	60.18s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 8.55s of the 1966.54s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	-2.3652	 = Validation score   (-root_mean_squared_error)
# 	11.87s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1951.78s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.333, 'LightGBMXT_BAG_L1': 0.267, 'LightGBM_BAG_L1': 0.267, 'RandomForestMSE_BAG_L1': 0.067, 'NeuralNetFastAI_BAG_L1': 0.067}
# 	-1.4989	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 650.39s of the 1951.55s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	-1.5078	 = Validation score   (-root_mean_squared_error)
# 	8.57s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 637.88s of the 1939.04s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	-1.5033	 = Validation score   (-root_mean_squared_error)
# 	10.2s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 624.59s of the 1925.75s of remaining time.
# 	-1.5295	 = Validation score   (-root_mean_squared_error)
# 	49.72s	 = Training   runtime
# 	1.52s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 572.92s of the 1874.08s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	-1.5057	 = Validation score   (-root_mean_squared_error)
# 	66.06s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 504.05s of the 1805.21s of remaining time.
# 	-1.503	 = Validation score   (-root_mean_squared_error)
# 	9.26s	 = Training   runtime
# 	1.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 492.81s of the 1793.97s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	-1.6639	 = Validation score   (-root_mean_squared_error)
# 	29.95s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 460.29s of the 1761.45s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.69%)
# 	-1.5166	 = Validation score   (-root_mean_squared_error)
# 	16.27s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 440.11s of the 1741.27s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.24%)
# 	-1.5313	 = Validation score   (-root_mean_squared_error)
# 	39.83s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 396.98s of the 1698.14s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.89%)
# 	-1.5114	 = Validation score   (-root_mean_squared_error)
# 	33.15s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 361.16s of the 1662.31s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	-1.5113	 = Validation score   (-root_mean_squared_error)
# 	51.97s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 306.47s of the 1607.63s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.23%)
# 	-1.7343	 = Validation score   (-root_mean_squared_error)
# 	46.24s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 257.77s of the 1558.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.50%)
# 	-1.5018	 = Validation score   (-root_mean_squared_error)
# 	21.48s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 232.36s of the 1533.51s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	-1.6471	 = Validation score   (-root_mean_squared_error)
# 	137.72s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 91.82s of the 1392.97s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=1.59%)
# 	-1.4972	 = Validation score   (-root_mean_squared_error)
# 	74.94s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 13.18s of the 1314.34s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	-1.5118	 = Validation score   (-root_mean_squared_error)
# 	12.81s	 = Training   runtime
# 	0.97s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 1296.32s of remaining time.
# 	Ensemble Weights: {'ExtraTreesMSE_BAG_L2': 0.28, 'LightGBMLarge_BAG_L2': 0.24, 'CatBoost_r9_BAG_L2': 0.16, 'NeuralNetTorch_BAG_L2': 0.08, 'NeuralNetTorch_r79_BAG_L2': 0.08, 'LightGBMXT_BAG_L2': 0.04, 'LightGBM_BAG_L2': 0.04, 'CatBoost_BAG_L2': 0.04, 'NeuralNetFastAI_BAG_L2': 0.04}
# 	-1.4796	 = Validation score   (-root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L3 models ...
# Fitting model: LightGBMXT_BAG_L3 ... Training model for up to 575.98s of the 1296.19s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	-1.5126	 = Validation score   (-root_mean_squared_error)
# 	7.79s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_BAG_L3 ... Training model for up to 565.55s of the 1285.76s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	-1.5082	 = Validation score   (-root_mean_squared_error)
# 	10.33s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L3 ... Training model for up to 551.5s of the 1271.71s of remaining time.
# 	-1.5297	 = Validation score   (-root_mean_squared_error)
# 	41.04s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: CatBoost_BAG_L3 ... Training model for up to 508.87s of the 1229.08s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	-1.4979	 = Validation score   (-root_mean_squared_error)
# 	34.0s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L3 ... Training model for up to 472.28s of the 1192.5s of remaining time.
# 	-1.532	 = Validation score   (-root_mean_squared_error)
# 	9.99s	 = Training   runtime
# 	1.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L3 ... Training model for up to 460.61s of the 1180.82s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	-1.6342	 = Validation score   (-root_mean_squared_error)
# 	34.03s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: XGBoost_BAG_L3 ... Training model for up to 423.94s of the 1144.15s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.74%)
# 	-1.5183	 = Validation score   (-root_mean_squared_error)
# 	17.08s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L3 ... Training model for up to 401.99s of the 1122.2s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	-1.5221	 = Validation score   (-root_mean_squared_error)
# 	36.04s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 362.27s of the 1082.49s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	-1.5261	 = Validation score   (-root_mean_squared_error)
# 	36.3s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L3 ... Training model for up to 323.15s of the 1043.36s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	-1.5043	 = Validation score   (-root_mean_squared_error)
# 	31.5s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L3 ... Training model for up to 288.52s of the 1008.73s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.24%)
# 	Warning: Exception caused NeuralNetTorch_r79_BAG_L3 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=6104, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 404, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 855, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 208, in _fit
#     self._train_net(
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 360, in _train_net
#     torch.save(self.model, net_filename)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\torch\serialization.py", line 618, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\torch\serialization.py", line 492, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\torch\serialization.py", line 463, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: File NYUS2_1_malus\models\NeuralNetTorch_r79_BAG_L3\S1F7\temp_model.pt cannot be opened.
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 855, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 286, in _fit
#     self._fit_folds(
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 717, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 663, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 605, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 568, in _process_fold_results
#     raise processed_exception
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 534, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time = self.ray.get(finished)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\ray\_private\worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::_ray_fit() (pid=6104, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 404, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 855, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 208, in _fit
#     self._train_net(
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 360, in _train_net
#     torch.save(self.model, net_filename)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\torch\serialization.py", line 618, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\torch\serialization.py", line 492, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\torch\serialization.py", line 463, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: File NYUS2_1_malus\models\NeuralNetTorch_r79_BAG_L3\S1F7\temp_model.pt cannot be opened.
# Fitting model: LightGBM_r131_BAG_L3 ... Training model for up to 261.93s of the 982.14s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.56%)
# 2024-10-04 21:31:00,570	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-04 21:31:00,579	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-04 21:31:00,584	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-04 21:31:00,588	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-04 21:31:00,591	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-04 21:31:00,594	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-1.5106	 = Validation score   (-root_mean_squared_error)
# 	19.94s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L3 ... Training model for up to 237.9s of the 958.09s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	-1.6164	 = Validation score   (-root_mean_squared_error)
# 	147.71s	 = Training   runtime
# 	1.27s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L3 ... Training model for up to 87.06s of the 807.27s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=1.73%)
# 	-1.504	 = Validation score   (-root_mean_squared_error)
# 	70.93s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L3 ... Training model for up to 12.0s of the 732.21s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	-1.5063	 = Validation score   (-root_mean_squared_error)
# 	8.03s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 360.0s of the 718.85s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L3': 0.48, 'NeuralNetTorch_BAG_L3': 0.12, 'LightGBMLarge_BAG_L3': 0.12, 'LightGBM_BAG_L3': 0.08, 'RandomForestMSE_BAG_L3': 0.08, 'LightGBM_r131_BAG_L3': 0.04, 'NeuralNetFastAI_r191_BAG_L3': 0.04, 'CatBoost_r9_BAG_L3': 0.04}
# 	-1.4931	 = Validation score   (-root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L4 models ...
# Fitting model: LightGBMXT_BAG_L4 ... Training model for up to 479.08s of the 718.71s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	-1.53	 = Validation score   (-root_mean_squared_error)
# 	8.2s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L4 ... Training model for up to 468.24s of the 707.87s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	-1.538	 = Validation score   (-root_mean_squared_error)
# 	10.21s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L4 ... Training model for up to 453.59s of the 693.21s of remaining time.
# 	-1.5464	 = Validation score   (-root_mean_squared_error)
# 	41.16s	 = Training   runtime
# 	1.86s	 = Validation runtime
# Fitting model: CatBoost_BAG_L4 ... Training model for up to 410.01s of the 649.64s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	-1.5196	 = Validation score   (-root_mean_squared_error)
# 	37.99s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L4 ... Training model for up to 368.7s of the 608.33s of remaining time.
# 	-1.5509	 = Validation score   (-root_mean_squared_error)
# 	9.83s	 = Training   runtime
# 	1.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 356.85s of the 596.49s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	-1.6646	 = Validation score   (-root_mean_squared_error)
# 	34.54s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 319.13s of the 558.76s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.77%)
# 2024-10-04 21:38:00,913	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-04 21:38:00,920	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-10-04 21:38:00,923	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-1.5425	 = Validation score   (-root_mean_squared_error)
# 	18.19s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 295.88s of the 535.5s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	-1.5393	 = Validation score   (-root_mean_squared_error)
# 	34.73s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L4 ... Training model for up to 257.61s of the 497.24s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	-1.57	 = Validation score   (-root_mean_squared_error)
# 	36.1s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L4 ... Training model for up to 218.36s of the 457.98s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.62%)
# 	-1.5222	 = Validation score   (-root_mean_squared_error)
# 	31.17s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L4 ... Training model for up to 183.86s of the 423.49s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	-1.693	 = Validation score   (-root_mean_squared_error)
# 	45.35s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L4 ... Training model for up to 135.58s of the 375.2s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	-1.5474	 = Validation score   (-root_mean_squared_error)
# 	19.87s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L4 ... Training model for up to 112.13s of the 351.76s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	-1.6591	 = Validation score   (-root_mean_squared_error)
# 	96.09s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L4 ... Training model for up to 12.52s of the 252.14s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=1.84%)
# 	-3.0797	 = Validation score   (-root_mean_squared_error)
# 	11.09s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L5 ... Training model for up to 360.0s of the 234.59s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L4': 0.353, 'RandomForestMSE_BAG_L4': 0.235, 'NeuralNetTorch_BAG_L4': 0.176, 'LightGBMXT_BAG_L4': 0.118, 'CatBoost_r177_BAG_L4': 0.118}
# 	-1.5137	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L5 models ...
# Fitting model: LightGBMXT_BAG_L5 ... Training model for up to 234.53s of the 234.36s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	-1.554	 = Validation score   (-root_mean_squared_error)
# 	7.99s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_BAG_L5 ... Training model for up to 223.63s of the 223.46s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	-1.5421	 = Validation score   (-root_mean_squared_error)
# 	11.72s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L5 ... Training model for up to 208.08s of the 207.91s of remaining time.
# 	-1.5671	 = Validation score   (-root_mean_squared_error)
# 	43.05s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: CatBoost_BAG_L5 ... Training model for up to 162.83s of the 162.67s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	-1.5376	 = Validation score   (-root_mean_squared_error)
# 	41.34s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L5 ... Training model for up to 118.55s of the 118.39s of remaining time.
# 	-1.5625	 = Validation score   (-root_mean_squared_error)
# 	9.67s	 = Training   runtime
# 	1.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L5 ... Training model for up to 107.09s of the 106.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	-1.6771	 = Validation score   (-root_mean_squared_error)
# 	33.99s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: XGBoost_BAG_L5 ... Training model for up to 70.3s of the 70.14s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.77%)
# 	-1.5575	 = Validation score   (-root_mean_squared_error)
# 	18.63s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L5 ... Training model for up to 46.37s of the 46.2s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	-1.5691	 = Validation score   (-root_mean_squared_error)
# 	35.17s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: WeightedEnsemble_L6 ... Training model for up to 360.0s of the 6.44s of remaining time.
# 	Ensemble Weights: {'ExtraTreesMSE_BAG_L2': 0.32, 'LightGBM_r131_BAG_L2': 0.2, 'NeuralNetTorch_BAG_L2': 0.16, 'CatBoost_r9_BAG_L2': 0.16, 'LightGBM_BAG_L3': 0.08, 'LightGBM_BAG_L2': 0.04, 'CatBoost_BAG_L2': 0.04}
# 	-1.4838	 = Validation score   (-root_mean_squared_error)
# 	0.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2665.65s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("NYUS2_1_malus")
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-1.371	 = Validation score   (-root_mean_squared_error)
# 	273.24s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 124.9s of the 368.54s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	-1.3666	 = Validation score   (-root_mean_squared_error)
# 	25.49s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 99.14s of the 342.78s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, stopping training early. (Stopping on epoch 6)
# 	Ran out of time, stopping training early. (Stopping on epoch 6)
# 	Ran out of time, stopping training early. (Stopping on epoch 7)
# 	Ran out of time, stopping training early. (Stopping on epoch 7)
# 	Ran out of time, stopping training early. (Stopping on epoch 7)
# 	Ran out of time, stopping training early. (Stopping on epoch 7)
# 	Ran out of time, stopping training early. (Stopping on epoch 8)
# 	Ran out of time, stopping training early. (Stopping on epoch 8)
# 	Ran out of time, stopping training early. (Stopping on epoch 10)
# 	Ran out of time, stopping training early. (Stopping on epoch 12)
# 	-1.3627	 = Validation score   (-root_mean_squared_error)
# 	94.77s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L4 ... Training model for up to 3.83s of the 247.47s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 4. Best iteration is:
# 	[4]	valid_set's rmse: 4.55369
# 	Time limit exceeded... Skipping LightGBMLarge_BAG_L4.
# Fitting model: CatBoost_r177_BAG_L4 ... Training model for up to 3.25s of the 246.9s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 27.
# 	Ran out of time, early stopping on iteration 27.
# 	Ran out of time, early stopping on iteration 18.
# 	Ran out of time, early stopping on iteration 28.
# 	Ran out of time, early stopping on iteration 27.
# 	Ran out of time, early stopping on iteration 23.
# 	Ran out of time, early stopping on iteration 29.
# 	Ran out of time, early stopping on iteration 30.
# 	Ran out of time, early stopping on iteration 28.
# 	Ran out of time, early stopping on iteration 39.
# 	-1.6464	 = Validation score   (-root_mean_squared_error)
# 	3.05s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L4 ... Training model for up to 0.01s of the 243.66s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L4.
# Fitting model: WeightedEnsemble_L5 ... Training model for up to 360.0s of the 243.06s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L4': 0.462, 'RandomForestMSE_BAG_L4': 0.231, 'NeuralNetTorch_BAG_L4': 0.179, 'LightGBM_BAG_L4': 0.077, 'NeuralNetFastAI_BAG_L4': 0.051}
# 	-1.34	 = Validation score   (-root_mean_squared_error)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L5 models ...
# Fitting model: LightGBMXT_BAG_L5 ... Training model for up to 242.83s of the 242.76s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	-1.381	 = Validation score   (-root_mean_squared_error)
# 	9.83s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L5 ... Training model for up to 232.82s of the 232.74s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	-1.3716	 = Validation score   (-root_mean_squared_error)
# 	11.92s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L5 ... Training model for up to 220.72s of the 220.65s of remaining time.
# 	-1.3931	 = Validation score   (-root_mean_squared_error)
# 	23.99s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: CatBoost_BAG_L5 ... Training model for up to 195.62s of the 195.55s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# 	-1.3618	 = Validation score   (-root_mean_squared_error)
# 	36.39s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L5 ... Training model for up to 159.02s of the 158.95s of remaining time.
# 	-1.3849	 = Validation score   (-root_mean_squared_error)
# 	5.47s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L5 ... Training model for up to 152.61s of the 152.54s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with SequentialLocalFoldFittingStrategy
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	Ran out of time, stopping training early. (Stopping on epoch 11)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	Ran out of time, stopping training early. (Stopping on epoch 11)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	Ran out of time, stopping training early. (Stopping on epoch 12)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	Ran out of time, stopping training early. (Stopping on epoch 15)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	Ran out of time, stopping training early. (Stopping on epoch 18)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	Ran out of time, stopping training early. (Stopping on epoch 23)
# C:\Users\LLLR\AppData\Local\R-MINI~1\envs\ag\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-1.3809	 = Validation score   (-root_mean_squared_error)
# 	145.97s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: WeightedEnsemble_L6 ... Training model for up to 360.0s of the 5.47s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.292, 'CatBoost_BAG_L1': 0.264, 'ExtraTreesMSE_BAG_L2': 0.111, 'LightGBM_BAG_L1': 0.083, 'RandomForestMSE_BAG_L2': 0.083, 'NeuralNetFastAI_BAG_L2': 0.069, 'NeuralNetTorch_BAG_L2': 0.056, 'CatBoost_BAG_L2': 0.042}
# 	-1.2959	 = Validation score   (-root_mean_squared_error)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2691.04s ... Best model: "WeightedEnsemble_L6"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("NYUS.2")

# %%
#The best model with best performance during training
predictor_LT50.get_model_best()
# Out:
# C:\Users\LLLR\AppData\Local\Temp\ipykernel_19252\2259236172.py:2: DeprecationWarning: `get_model_best` has been deprecated and will be removed in version 1.2. Please use `model_best` instead. This will raise an error in the future!
#   predictor_LT50.get_model_best()
# 'WeightedEnsemble_L3'
